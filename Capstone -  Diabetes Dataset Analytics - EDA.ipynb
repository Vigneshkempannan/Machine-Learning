# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import os

# %%
os.chdir("C:\\Users\\AADHI\\Desktop\\Capstone project\\CAPSTONE\\CAPSTONE")

# %%
df=pd.read_csv("merged_diabetic_dat_final.csv")

# %%
fd=pd.read_csv('merged_diabetic_dat_final.csv')
fd.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital    ...     citoglipton insulin  glyburide-metformin  \
# ...

# %%
zz=fd[fd['patient_nbr'].duplicated()]

# %%
zz.shape
# Out:
# (30248, 50)

# %%
fgh=zz.index

# %%
fgh
# Out:
# Int64Index([    79,     81,    143,    175,    307,    332,    335,    338,
#                348,    404,
#             ...
#             101746, 101747, 101750, 101757, 101759, 101760, 101761, 101762,
#             101763, 101764],
#            dtype='int64', length=30248)

# %%
df2=fd.drop(axis=0, index=fgh)

# %%
df2.shape
# Out:
# (71518, 50)

# %%
a=df2[df2['discharge_disposition_id'].isin([11,13,14,19,20,21])]

# %%
b=a.index

# %%
a.shape
# Out:
# (1545, 50)

# %%
fd.shape
# Out:
# (101766, 50)

# %%
df=df2.drop(axis=1, index=b)

# %%
df.head().T
# Out:
#                                                  0          1  \
# encounter_id                               2278392     149190
# patient_nbr                                8222157   55629189
# race                                     Caucasian  Caucasian
# gender                                      Female     Female
# age                                         [0-10)    [10-20)
# weight                                           ?          ?
# admission_type_id                                6          1
# discharge_disposition_id                        25          1
# admission_source_id                              1          7
# time_in_hospital                                 1          3
# payer_code                                       ?          ?
# medical_specialty         Pediatrics-Endocrinology          ?
# num_lab_procedures                              41         59
# num_procedures                                   0          0
# ...

# %%
df.shape
# Out:
# (69973, 50)

# %%
df=df.replace('?',np.nan)

# %%
df.isnull().sum()
# Out:
# encounter_id                    0
# patient_nbr                     0
# race                         1918
# gender                          0
# age                             0
# weight                      67185
# admission_type_id               0
# discharge_disposition_id        0
# admission_source_id             0
# time_in_hospital                0
# payer_code                  30415
# medical_specialty           33639
# num_lab_procedures              0
# num_procedures                  0
# num_medications                 0
# number_outpatient               0
# number_emergency                0
# number_inpatient                0
# diag_1                         10
# diag_2                        293
# diag_3                       1224
# number_diagnoses                0
# max_glu_serum                   0
# A1Cresult                       0
# metformin                       0
# repaglinide                     0
# nateglinide                     0
# ...

# %%
plt.figure(figsize=(12,8))
plt.subplot(1,2,1)
df["gender"].value_counts().plot(kind="bar")
plt.title('gender ')
plt.subplot(1,2,2)
df["race"].value_counts().plot(kind="bar")
plt.title('race value counts')
plt.show()

# %%
total_records= len(df)
columns = ["gender","race","age","admission_source_id"]
plt.figure(figsize=(12,10))
j=0
for i in columns:
    j +=1
    plt.subplot(4,2,j)
    #sns.countplot(hrdata[i])
    sns.countplot(data=df,x= i,hue="readmitted")
    plt.xticks(rotation=90)
    # Custom the subplot layout
plt.subplots_adjust(bottom=-0.9, top=2)
plt.show()

# %%
total_records= len(df)
columns = ["max_glu_serum","A1Cresult","change","diabetesMed","insulin"]
plt.figure(figsize=(12,10))
j=0
for i in columns:
    j +=1
    plt.subplot(4,2,j)
    #sns.countplot(hrdata[i])
    sns.countplot(data=df,x= i,hue="readmitted")
#     plt.xticks(rotation=90)
    # Custom the subplot layout
plt.subplots_adjust(bottom=-0.9, top=2)
plt.show()

# %%
total_records= len(df)
columns = ["admission_type_id","discharge_disposition_id","time_in_hospital",'num_procedures']
plt.figure(figsize=(12,10))
j=0
for i in columns:
    j +=1
    plt.subplot(4,2,j)
    #sns.countplot(hrdata[i])
    sns.countplot(data=df,x= i,hue="readmitted")
#     plt.xticks(rotation=90)
    # Custom the subplot layout
plt.subplots_adjust(bottom=-0.9, top=2)
plt.show()
